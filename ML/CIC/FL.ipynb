# %% [markdown]
# # Flower FLML Experiments - Measured
# ## Description
# This notebook is for running federated learning machine learning experiment for ISDC project. This notebook uses flower framework for implementing federated learning concepts.

# %% [markdown]
# ## Imports

# %%
from pyarrow import csv
import pyarrow.parquet as pq
import pandas as pd
import numpy as np
import glob

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import flwr as fl
from flwr.common import Metrics
from flwr.simulation.ray_transport.utils import enable_tf_gpu_growth

# %%
import math
from typing import Dict, List, Tuple

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %%
from tensorflow.keras.models import load_model

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, precision_recall_curve, auc, average_precision_score, f1_score

# %% [markdown]
# ## Functions and Classes

# %%
# ANN Model Creationg Function
def create_ann_model(input_shape=(94,), hidden_units=None):
    """
    Create a feedforward neural network model for binary classification with
    the specified input shape.

    Parameters:
    - input_shape: Tuple specifying the shape of the input data.
    - hidden_units: List of integers specifying the number of units in each hidden layer.
                    Default is [64, 32].

    Returns:
    - A compiled Keras model.
    """

    if hidden_units is None:
        hidden_units = [64, 32]

    model = Sequential()

    # Input layer
    model.add(Dense(hidden_units[0], activation='relu', input_shape=input_shape))
    model.add(Dropout(0.2))

    # Hidden layers
    for units in hidden_units[1:]:
        model.add(Dense(units, activation='relu'))
        model.add(Dropout(0.2))

    # Output layer for binary classification
    model.add(Dense(1, activation='sigmoid'))

    # Compile the model
    model.compile(loss='binary_crossentropy', optimizer='nadam', metrics=['accuracy'])
    return model

# %%
def model_report_list(model, df_test):
    result = []
    
    x_test = df_test.iloc[:, :-1]
    y_test = df_test["Class"]
    
    # Get model predictions for the test data
    y_pred_prob = model.predict(x_test, verbose=0)
    y_pred = (y_pred_prob > 0.5).astype("int32")
    
    df_test["PLabel"] = y_pred
    
    # # Calculate overall accuracy
    # overall_accuracy = accuracy_score(y_test, y_pred)
    # result.append(('Overall Accuracy', overall_accuracy))

    # Calculate F1 Score
    f1 = f1_score(y_test, y_pred)
    result.append(('F1 Score', f1))

    # Calculate AUC
    auc_score = roc_auc_score(y_test, y_pred_prob)
    result.append(('AUC', auc_score))
    
    # # Calculate AUC-PR
    # precision, recall, _ = precision_recall_curve(y_test, y_pred_prob)
    # auc_pr_score = auc(recall, precision)
    # result.append(('AUC-PR', auc_pr_score))
    
    # # Calculate and print per-class accuracy
    # unique_classes = np.unique(y_test)
    # confusion_mat = confusion_matrix(y_test, y_pred, labels=unique_classes)
    # per_class_accuracy = np.diag(confusion_mat) / np.sum(confusion_mat, axis=1)
    # for class_id, accuracy in zip(unique_classes, per_class_accuracy):
    #     result.append((f'Accuracy Class {class_id}', accuracy))

    # # Calculate False Positives and False Negatives
    # FP = confusion_mat[0][1]
    # FN = confusion_mat[1][0]
    # result.append(('False Positives', FP))
    # result.append(('False Negatives', FN))
    
    return result

# %%
class FlowerClient(fl.client.NumPyClient):
    def __init__(self, x_train, y_train,model) -> None:
        # Create model
        self.model = model
        self.x_train, self.y_train = x_train, y_train

    def get_parameters(self, config):
        return self.model.get_weights()

    def fit(self, parameters, config):

        self.model.set_weights(parameters)
        self.model.fit(
             self.x_train,  self.y_train, epochs=3, batch_size=32, verbose=VERBOSE
        )
        return self.model.get_weights(), len(self.x_train), {}

# %%
def get_client_fn(dataset_partitions,model):
    """Return a function to be executed by the VirtualClientEngine in order to construct
    a client."""

    def client_fn(cid: str) -> fl.client.Client:
        """Construct a FlowerClient with its own dataset partition."""

        # Extract partition for client with id = cid
        x_train, y_train = dataset_partitions[int(cid)]
        
        # Create and return client
        return FlowerClient(x_train, y_train, model)

    return client_fn


def partition_dataset(x, y, num_clients):
    partition_size = math.floor(len(x) / num_clients)
    partitions = []
    for i in range(num_clients):
        idx_from, idx_to = i * partition_size, (i + 1) * partition_size
        partitions.append((x[idx_from:idx_to], y[idx_from:idx_to]))
    return partitions

def get_evaluate_fn(model,file_path):
    """Return an evaluation function for server-side (i.e. centralized) evaluation."""

    # The `evaluate` function will be called after every round by the strategy
    def evaluate(
        server_round: int,
        parameters: fl.common.NDArrays,
        config: Dict[str, fl.common.Scalar],
    ):
        model.set_weights(parameters)  # Update model with the latest parameters
        model.save(file_path)
        # model_report(model,x_test,y_test)
        return 

    return evaluate

# %% [markdown]
# ## Data Preparation - Measured

# %%
def get_partitions(data_path):
    partitions = []
    
    for f in glob.glob(data_path):
        data = pd.read_csv(f)

        data.columns = data.columns.str.strip()
        data = data[data["Class"] != ' null']
        data["Class"] = data["Class"].replace({' "-1"' : 0 , ' "Facet"' : 1 })
        data["Class"] = data["Class"].replace({'-1' : 0, 'Facet' : 1 })
        data["Class"] = data["Class"].replace({' -1' : 0, ' Facet' : 1 })
        data["Class"] = data["Class"].replace(np.nan,'benign')
        
        data = data.sample(frac = 1).reset_index(drop=True)
        
        x_data = data.iloc[:,:-1]
        y_data = data["Class"]
    
        partitions.append((x_data.to_numpy(),y_data.to_numpy()))

    return partitions

# %% [markdown]
# ## Testing Data Preparation

# %%
df = pq.read_table("/data/important_data_test.parquet").to_pandas()

# %%
df_b = df[df['BLabel'] == 0].reset_index(drop=True)
df_a = df[df['BLabel'] == 1].reset_index(drop=True)

# %%
df_b = df_b.sample(n=len(df_a),random_state=5467).reset_index(drop=True)

# %%
df = pd.concat([df_a,df_b],ignore_index=True)

# %%
test_data = pd.DataFrame()
test_data = pd.DataFrame(df['Packet Size Distribution'].to_list())
test_data["Class"] = df["BLabel"]

# %% [markdown]
# ## Global Setting

# %%
VERBOSE = 0
NUM_CLIENTS = 18

# With a dictionary, you tell Flower's VirtualClientEngine that each
# client needs exclusive access to these many resources in order to run
client_resources = {"num_cpus":2,"num_gpus": 2}

# %% [markdown]
# ## Model Training

# %%
# Enable GPU growth in your main process
enable_tf_gpu_growth()
# Out:
# 2024-02-01 09:25:06.001458: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-01 09:25:06.001695: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-01 09:25:06.034955: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-01 09:25:06.035216: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-01 09:25:06.035414: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-01 09:25:06.035600: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
result = []

partitions = get_partitions("./dataset/isdc/*")

for _ in range(50):

    hidden_units = [64,32]
    output_model = f"./models/i{_}.keras"
    
    model = create_ann_model(hidden_units=hidden_units)
    
    
    strategy = fl.server.strategy.FedAvg(
    fraction_fit=1,
    # min_fit_clients=10,
    fraction_evaluate = 1,
    min_available_clients = NUM_CLIENTS, 
    evaluate_fn = get_evaluate_fn(model,output_model),
    )
    
    
    # Start simulation
    history = fl.simulation.start_simulation(
    client_fn=get_client_fn(partitions,model),
    num_clients=NUM_CLIENTS,
    config=fl.server.ServerConfig(num_rounds=1),
    strategy=strategy,
    client_resources=client_resources,
    actor_kwargs={
    "on_actor_init_fn": enable_tf_gpu_growth  
    },
    )
    del history
    del strategy
    del model
    
    model = load_model(output_model)
    s = model_report_list(model,test_data.copy())

    result.append(s)
    del model
# Out:
# INFO flwr 2024-02-01 09:27:22,004 | app.py:178 | Starting Flower simulation, config: ServerConfig(num_rounds=1, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=1, round_timeout=None)
# 2024-02-01 09:27:25,455	INFO worker.py:1621 -- Started a local Ray instance.
# INFO flwr 2024-02-01 09:27:26,303 | app.py:213 | Flower VCE: Ray initialized with resources: {'node:__internal_head__': 1.0, 'node:35.16.80.216': 1.0, 'CPU': 64.0, 'GPU': 2.0, 'accelerator_type:G': 1.0, 'object_store_memory': 157559513088.0, 'memory': 357638863872.0}
# INFO:flwr:Flower VCE: Ray initialized with resources: {'node:__internal_head__': 1.0, 'node:35.16.80.216': 1.0, 'CPU': 64.0, 'GPU': 2.0, 'accelerator_type:G': 1.0, 'object_store_memory': 157559513088.0, 'memory': 357638863872.0}
# INFO flwr 2024-02-01 09:27:26,303 | app.py:219 | Optimize your simulation with Flower VCE: https://flower.dev/docs/framework/how-to-run-simulations.html
# INFO:flwr:Optimize your simulation with Flower VCE: https://flower.dev/docs/framework/how-to-run-simulations.html
# INFO flwr 2024-02-01 09:27:26,304 | app.py:242 | Flower VCE: Resources for each Virtual Client: {'num_cpus': 2, 'num_gpus': 2}
# INFO:flwr:Flower VCE: Resources for each Virtual Client: {'num_cpus': 2, 'num_gpus': 2}
# INFO flwr 2024-02-01 09:27:26,312 | app.py:288 | Flower VCE: Creating VirtualClientEngineActorPool with 1 actors
# INFO:flwr:Flower VCE: Creating VirtualClientEngineActorPool with 1 actors
# INFO flwr 2024-02-01 09:27:26,313 | server.py:89 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2024-02-01 09:27:26,313 | server.py:276 | Requesting initial parameters from one random client
# INFO:flwr:Requesting initial parameters from one random client
# (pid=2039876) 2024-02-01 09:27:26.964234: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=2039876) 2024-02-01 09:27:26.964272: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=2039876) 2024-02-01 09:27:26.965380: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=2039876) 2024-02-01 09:27:26.970557: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# (pid=2039876) To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (pid=2039876) 2024-02-01 09:27:27.616457: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (DefaultActor pid=2039876) 2024-02-01 09:27:28.384524: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2039876) 2024-02-01 09:27:28.384748: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2039876) 2024-02-01 09:27:28.420326: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2039876) 2024-02-01 09:27:28.420602: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2039876) 2024-02-01 09:27:28.420799: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2039876) 2024-02-01 09:27:28.420986: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2039876) 2024-02-01 09:27:28.540579: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2039876) 2024-02-01 09:27:28.540805: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2039876) 2024-02-01 09:27:28.540992: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2039876) 2024-02-01 09:27:28.541182: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2039876) 2024-02-01 09:27:28.541356: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2039876) 2024-02-01 09:27:28.541539: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2039876) 2024-02-01 09:27:28.549328: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2039876) 2024-02-01 09:27:28.549541: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2039876) 2024-02-01 09:27:28.549733: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2039876) 2024-02-01 09:27:28.549921: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2039876) 2024-02-01 09:27:28.550113: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2039876) 2024-02-01 09:27:28.550271: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21875 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:41:00.0, compute capability: 8.9
# (DefaultActor pid=2039876) 2024-02-01 09:27:28.550640: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2039876) 2024-02-01 09:27:28.550793: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 21889 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:61:00.0, compute capability: 8.9
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# INFO flwr 2024-02-01 09:27:28,642 | server.py:280 | Received initial parameters from one random client
# INFO:flwr:Received initial parameters from one random client
# INFO flwr 2024-02-01 09:27:28,643 | server.py:91 | Evaluating initial parameters
# INFO:flwr:Evaluating initial parameters
# INFO flwr 2024-02-01 09:27:28,664 | server.py:104 | FL starting
# INFO:flwr:FL starting
# DEBUG flwr 2024-02-01 09:27:28,665 | server.py:222 | fit_round 1: strategy sampled 18 clients (out of 18)
# DEBUG:flwr:fit_round 1: strategy sampled 18 clients (out of 18)
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) 2024-02-01 09:27:30.425325: I external/local_xla/xla/service/service.cc:168] XLA service 0x7ed739a3f400 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# (DefaultActor pid=2039876) 2024-02-01 09:27:30.425364: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# (DefaultActor pid=2039876) 2024-02-01 09:27:30.425384: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# (DefaultActor pid=2039876) 2024-02-01 09:27:30.434981: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# (DefaultActor pid=2039876) 2024-02-01 09:27:30.449017: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# (DefaultActor pid=2039876) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (DefaultActor pid=2039876) I0000 00:00:1706797650.531781 2040206 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# DEBUG flwr 2024-02-01 09:28:07,705 | server.py:236 | fit_round 1 received 18 results and 0 failures
# DEBUG:flwr:fit_round 1 received 18 results and 0 failures
# WARNING flwr 2024-02-01 09:28:07,721 | fedavg.py:242 | No fit_metrics_aggregation_fn provided
# WARNING:flwr:No fit_metrics_aggregation_fn provided
# DEBUG flwr 2024-02-01 09:28:07,736 | server.py:173 | evaluate_round 1: strategy sampled 18 clients (out of 18)
# DEBUG:flwr:evaluate_round 1: strategy sampled 18 clients (out of 18)
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2039876) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# DEBUG flwr 2024-02-01 09:28:08,819 | server.py:187 | evaluate_round 1 received 0 results and 18 failures
# DEBUG:flwr:evaluate_round 1 received 0 results and 18 failures
# INFO flwr 2024-02-01 09:28:08,820 | server.py:153 | FL finished in 40.154951275966596
# INFO:flwr:FL finished in 40.154951275966596
# INFO flwr 2024-02-01 09:28:08,820 | app.py:226 | app_fit: losses_distributed []
# INFO:flwr:app_fit: losses_distributed []
# INFO flwr 2024-02-01 09:28:08,821 | app.py:227 | app_fit: metrics_distributed_fit {}
# INFO:flwr:app_fit: metrics_distributed_fit {}
# INFO flwr 2024-02-01 09:28:08,822 | app.py:228 | app_fit: metrics_distributed {}
# INFO:flwr:app_fit: metrics_distributed {}
# INFO flwr 2024-02-01 09:28:08,823 | app.py:229 | app_fit: losses_centralized []
# INFO:flwr:app_fit: losses_centralized []
# INFO flwr 2024-02-01 09:28:08,824 | app.py:230 | app_fit: metrics_centralized {}
# INFO:flwr:app_fit: metrics_centralized {}
# WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# INFO flwr 2024-02-01 09:28:09,014 | app.py:178 | Starting Flower simulation, config: ServerConfig(num_rounds=1, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=1, round_timeout=None)
# 2024-02-01 09:28:12,524	INFO worker.py:1621 -- Started a local Ray instance.
# INFO flwr 2024-02-01 09:28:13,407 | app.py:213 | Flower VCE: Ray initialized with resources: {'node:__internal_head__': 1.0, 'node:35.16.80.216': 1.0, 'CPU': 64.0, 'object_store_memory': 157555170508.0, 'memory': 357628731188.0, 'accelerator_type:G': 1.0, 'GPU': 2.0}
# INFO:flwr:Flower VCE: Ray initialized with resources: {'node:__internal_head__': 1.0, 'node:35.16.80.216': 1.0, 'CPU': 64.0, 'object_store_memory': 157555170508.0, 'memory': 357628731188.0, 'accelerator_type:G': 1.0, 'GPU': 2.0}
# INFO flwr 2024-02-01 09:28:13,408 | app.py:219 | Optimize your simulation with Flower VCE: https://flower.dev/docs/framework/how-to-run-simulations.html
# INFO:flwr:Optimize your simulation with Flower VCE: https://flower.dev/docs/framework/how-to-run-simulations.html
# INFO flwr 2024-02-01 09:28:13,408 | app.py:242 | Flower VCE: Resources for each Virtual Client: {'num_cpus': 2, 'num_gpus': 2}
# INFO:flwr:Flower VCE: Resources for each Virtual Client: {'num_cpus': 2, 'num_gpus': 2}
# INFO flwr 2024-02-01 09:28:13,417 | app.py:288 | Flower VCE: Creating VirtualClientEngineActorPool with 1 actors
# INFO:flwr:Flower VCE: Creating VirtualClientEngineActorPool with 1 actors
# INFO flwr 2024-02-01 09:28:13,418 | server.py:89 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2024-02-01 09:28:13,418 | server.py:276 | Requesting initial parameters from one random client
# INFO:flwr:Requesting initial parameters from one random client
# (pid=2054063) 2024-02-01 09:28:14.068875: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=2054063) 2024-02-01 09:28:14.068914: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=2054063) 2024-02-01 09:28:14.070018: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=2054063) 2024-02-01 09:28:14.075041: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# (pid=2054063) To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (pid=2054063) 2024-02-01 09:28:14.729923: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (DefaultActor pid=2054063) 2024-02-01 09:28:15.507318: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2054063) 2024-02-01 09:28:15.507550: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2054063) 2024-02-01 09:28:15.542999: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2054063) 2024-02-01 09:28:15.543280: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2054063) 2024-02-01 09:28:15.543489: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2054063) 2024-02-01 09:28:15.543685: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2054063) 2024-02-01 09:28:15.666290: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2054063) 2024-02-01 09:28:15.666526: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2054063) 2024-02-01 09:28:15.666722: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2054063) 2024-02-01 09:28:15.666925: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2054063) 2024-02-01 09:28:15.667108: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2054063) 2024-02-01 09:28:15.667290: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2054063) 2024-02-01 09:28:15.674973: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2054063) 2024-02-01 09:28:15.675180: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2054063) 2024-02-01 09:28:15.675370: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2054063) 2024-02-01 09:28:15.675564: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2054063) 2024-02-01 09:28:15.675761: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2054063) 2024-02-01 09:28:15.675926: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21875 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:41:00.0, compute capability: 8.9
# (DefaultActor pid=2054063) 2024-02-01 09:28:15.676282: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2054063) 2024-02-01 09:28:15.676438: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 21889 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:61:00.0, compute capability: 8.9
# INFO flwr 2024-02-01 09:28:15,768 | server.py:280 | Received initial parameters from one random client
# INFO:flwr:Received initial parameters from one random client
# INFO flwr 2024-02-01 09:28:15,769 | server.py:91 | Evaluating initial parameters
# INFO:flwr:Evaluating initial parameters
# INFO flwr 2024-02-01 09:28:15,790 | server.py:104 | FL starting
# INFO:flwr:FL starting
# DEBUG flwr 2024-02-01 09:28:15,791 | server.py:222 | fit_round 1: strategy sampled 18 clients (out of 18)
# DEBUG:flwr:fit_round 1: strategy sampled 18 clients (out of 18)
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) 2024-02-01 09:28:17.581277: I external/local_xla/xla/service/service.cc:168] XLA service 0x7faa0968aa80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# (DefaultActor pid=2054063) 2024-02-01 09:28:17.581316: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# (DefaultActor pid=2054063) 2024-02-01 09:28:17.581337: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# (DefaultActor pid=2054063) 2024-02-01 09:28:17.590857: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# (DefaultActor pid=2054063) 2024-02-01 09:28:17.604731: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# (DefaultActor pid=2054063) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (DefaultActor pid=2054063) I0000 00:00:1706797697.689154 2054384 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# DEBUG flwr 2024-02-01 09:28:55,306 | server.py:236 | fit_round 1 received 18 results and 0 failures
# DEBUG:flwr:fit_round 1 received 18 results and 0 failures
# WARNING flwr 2024-02-01 09:28:55,330 | fedavg.py:242 | No fit_metrics_aggregation_fn provided
# WARNING:flwr:No fit_metrics_aggregation_fn provided
# DEBUG flwr 2024-02-01 09:28:55,351 | server.py:173 | evaluate_round 1: strategy sampled 18 clients (out of 18)
# DEBUG:flwr:evaluate_round 1: strategy sampled 18 clients (out of 18)
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# DEBUG flwr 2024-02-01 09:28:56,536 | server.py:187 | evaluate_round 1 received 0 results and 18 failures
# DEBUG:flwr:evaluate_round 1 received 0 results and 18 failures
# INFO flwr 2024-02-01 09:28:56,537 | server.py:153 | FL finished in 40.74593980802456
# INFO:flwr:FL finished in 40.74593980802456
# INFO flwr 2024-02-01 09:28:56,537 | app.py:226 | app_fit: losses_distributed []
# INFO:flwr:app_fit: losses_distributed []
# INFO flwr 2024-02-01 09:28:56,538 | app.py:227 | app_fit: metrics_distributed_fit {}
# INFO:flwr:app_fit: metrics_distributed_fit {}
# INFO flwr 2024-02-01 09:28:56,538 | app.py:228 | app_fit: metrics_distributed {}
# INFO:flwr:app_fit: metrics_distributed {}
# INFO flwr 2024-02-01 09:28:56,539 | app.py:229 | app_fit: losses_centralized []
# INFO:flwr:app_fit: losses_centralized []
# INFO flwr 2024-02-01 09:28:56,539 | app.py:230 | app_fit: metrics_centralized {}
# INFO:flwr:app_fit: metrics_centralized {}
# (DefaultActor pid=2054063) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# INFO flwr 2024-02-01 09:28:57,012 | app.py:178 | Starting Flower simulation, config: ServerConfig(num_rounds=1, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=1, round_timeout=None)
# 2024-02-01 09:29:01,569	INFO worker.py:1621 -- Started a local Ray instance.
# INFO flwr 2024-02-01 09:29:02,461 | app.py:213 | Flower VCE: Ray initialized with resources: {'memory': 357617529037.0, 'node:__internal_head__': 1.0, 'node:35.16.80.216': 1.0, 'CPU': 64.0, 'GPU': 2.0, 'accelerator_type:G': 1.0, 'object_store_memory': 157550369587.0}
# INFO:flwr:Flower VCE: Ray initialized with resources: {'memory': 357617529037.0, 'node:__internal_head__': 1.0, 'node:35.16.80.216': 1.0, 'CPU': 64.0, 'GPU': 2.0, 'accelerator_type:G': 1.0, 'object_store_memory': 157550369587.0}
# INFO flwr 2024-02-01 09:29:02,462 | app.py:219 | Optimize your simulation with Flower VCE: https://flower.dev/docs/framework/how-to-run-simulations.html
# INFO:flwr:Optimize your simulation with Flower VCE: https://flower.dev/docs/framework/how-to-run-simulations.html
# INFO flwr 2024-02-01 09:29:02,462 | app.py:242 | Flower VCE: Resources for each Virtual Client: {'num_cpus': 2, 'num_gpus': 2}
# INFO:flwr:Flower VCE: Resources for each Virtual Client: {'num_cpus': 2, 'num_gpus': 2}
# INFO flwr 2024-02-01 09:29:02,470 | app.py:288 | Flower VCE: Creating VirtualClientEngineActorPool with 1 actors
# INFO:flwr:Flower VCE: Creating VirtualClientEngineActorPool with 1 actors
# INFO flwr 2024-02-01 09:29:02,471 | server.py:89 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2024-02-01 09:29:02,472 | server.py:276 | Requesting initial parameters from one random client
# INFO:flwr:Requesting initial parameters from one random client
# (pid=2068251) 2024-02-01 09:29:03.123424: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=2068251) 2024-02-01 09:29:03.123462: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=2068251) 2024-02-01 09:29:03.124561: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=2068251) 2024-02-01 09:29:03.129510: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# (pid=2068251) To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (pid=2068251) 2024-02-01 09:29:03.794551: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (DefaultActor pid=2068251) 2024-02-01 09:29:04.583648: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2068251) 2024-02-01 09:29:04.583880: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2068251) 2024-02-01 09:29:04.619956: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2068251) 2024-02-01 09:29:04.620209: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2068251) 2024-02-01 09:29:04.620407: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2068251) 2024-02-01 09:29:04.620594: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2068251) 2024-02-01 09:29:04.754347: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2068251) 2024-02-01 09:29:04.754595: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2068251) 2024-02-01 09:29:04.754795: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2068251) 2024-02-01 09:29:04.754993: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2068251) 2024-02-01 09:29:04.755179: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2068251) 2024-02-01 09:29:04.755365: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2068251) 2024-02-01 09:29:04.763238: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2068251) 2024-02-01 09:29:04.763458: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2068251) 2024-02-01 09:29:04.763662: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2068251) 2024-02-01 09:29:04.763867: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2068251) 2024-02-01 09:29:04.764074: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# ...
# (DefaultActor pid=2295548) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2295548) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2295548) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2295548) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2295548) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# DEBUG flwr 2024-02-01 09:42:20,204 | server.py:187 | evaluate_round 1 received 0 results and 18 failures
# DEBUG:flwr:evaluate_round 1 received 0 results and 18 failures
# INFO flwr 2024-02-01 09:42:20,204 | server.py:153 | FL finished in 40.38586870697327
# INFO:flwr:FL finished in 40.38586870697327
# INFO flwr 2024-02-01 09:42:20,205 | app.py:226 | app_fit: losses_distributed []
# INFO:flwr:app_fit: losses_distributed []
# INFO flwr 2024-02-01 09:42:20,205 | app.py:227 | app_fit: metrics_distributed_fit {}
# INFO:flwr:app_fit: metrics_distributed_fit {}
# INFO flwr 2024-02-01 09:42:20,205 | app.py:228 | app_fit: metrics_distributed {}
# INFO:flwr:app_fit: metrics_distributed {}
# (DefaultActor pid=2295548) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables. INFO flwr 2024-02-01 09:42:20,206 | app.py:229 | app_fit: losses_centralized []
#
# (DefaultActor pid=2295548) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# INFO:flwr:app_fit: losses_centralized []
# INFO flwr 2024-02-01 09:42:20,206 | app.py:230 | app_fit: metrics_centralized {}
# INFO:flwr:app_fit: metrics_centralized {}
# WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# INFO flwr 2024-02-01 09:42:20,389 | app.py:178 | Starting Flower simulation, config: ServerConfig(num_rounds=1, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=1, round_timeout=None)
# 2024-02-01 09:42:24,024	INFO worker.py:1621 -- Started a local Ray instance.
# INFO flwr 2024-02-01 09:42:24,902 | app.py:213 | Flower VCE: Ray initialized with resources: {'node:__internal_head__': 1.0, 'accelerator_type:G': 1.0, 'GPU': 2.0, 'memory': 357437408666.0, 'node:35.16.80.216': 1.0, 'CPU': 64.0, 'object_store_memory': 157473175142.0}
# INFO:flwr:Flower VCE: Ray initialized with resources: {'node:__internal_head__': 1.0, 'accelerator_type:G': 1.0, 'GPU': 2.0, 'memory': 357437408666.0, 'node:35.16.80.216': 1.0, 'CPU': 64.0, 'object_store_memory': 157473175142.0}
# INFO flwr 2024-02-01 09:42:24,902 | app.py:219 | Optimize your simulation with Flower VCE: https://flower.dev/docs/framework/how-to-run-simulations.html
# INFO:flwr:Optimize your simulation with Flower VCE: https://flower.dev/docs/framework/how-to-run-simulations.html
# INFO flwr 2024-02-01 09:42:24,903 | app.py:242 | Flower VCE: Resources for each Virtual Client: {'num_cpus': 2, 'num_gpus': 2}
# INFO:flwr:Flower VCE: Resources for each Virtual Client: {'num_cpus': 2, 'num_gpus': 2}
# INFO flwr 2024-02-01 09:42:24,911 | app.py:288 | Flower VCE: Creating VirtualClientEngineActorPool with 1 actors
# INFO:flwr:Flower VCE: Creating VirtualClientEngineActorPool with 1 actors
# INFO flwr 2024-02-01 09:42:24,912 | server.py:89 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2024-02-01 09:42:24,912 | server.py:276 | Requesting initial parameters from one random client
# INFO:flwr:Requesting initial parameters from one random client
# (pid=2309770) 2024-02-01 09:42:25.558017: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=2309770) 2024-02-01 09:42:25.558054: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=2309770) 2024-02-01 09:42:25.559159: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=2309770) 2024-02-01 09:42:25.564165: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# (pid=2309770) To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (pid=2309770) 2024-02-01 09:42:26.220008: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (DefaultActor pid=2309770) 2024-02-01 09:42:26.977213: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2309770) 2024-02-01 09:42:26.977433: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2309770) 2024-02-01 09:42:27.013708: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2309770) 2024-02-01 09:42:27.013973: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2309770) 2024-02-01 09:42:27.014169: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2309770) 2024-02-01 09:42:27.014352: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# INFO flwr 2024-02-01 09:42:27,256 | server.py:280 | Received initial parameters from one random client
# (DefaultActor pid=2309770) 2024-02-01 09:42:27.154188: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2309770) 2024-02-01 09:42:27.154422: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2309770) 2024-02-01 09:42:27.154613: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2309770) 2024-02-01 09:42:27.154804: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2309770) 2024-02-01 09:42:27.154981: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2309770) 2024-02-01 09:42:27.155156: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2309770) 2024-02-01 09:42:27.162795: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2309770) 2024-02-01 09:42:27.163011: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2309770) 2024-02-01 09:42:27.163220: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2309770) 2024-02-01 09:42:27.163415: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2309770) 2024-02-01 09:42:27.163615: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2309770) 2024-02-01 09:42:27.163778: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21871 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:41:00.0, compute capability: 8.9
# (DefaultActor pid=2309770) 2024-02-01 09:42:27.164149: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (DefaultActor pid=2309770) 2024-02-01 09:42:27.164305: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 21889 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:61:00.0, compute capability: 8.9
# (DefaultActor pid=2309770) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# INFO:flwr:Received initial parameters from one random client
# INFO flwr 2024-02-01 09:42:27,258 | server.py:91 | Evaluating initial parameters
# INFO:flwr:Evaluating initial parameters
# INFO flwr 2024-02-01 09:42:27,278 | server.py:104 | FL starting
# INFO:flwr:FL starting
# DEBUG flwr 2024-02-01 09:42:27,279 | server.py:222 | fit_round 1: strategy sampled 18 clients (out of 18)
# DEBUG:flwr:fit_round 1: strategy sampled 18 clients (out of 18)
# (DefaultActor pid=2309770) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2309770) 2024-02-01 09:42:29.000107: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f752fa11210 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# (DefaultActor pid=2309770) 2024-02-01 09:42:29.000139: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# (DefaultActor pid=2309770) 2024-02-01 09:42:29.000153: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# (DefaultActor pid=2309770) 2024-02-01 09:42:29.009293: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# (DefaultActor pid=2309770) 2024-02-01 09:42:29.024303: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# (DefaultActor pid=2309770) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (DefaultActor pid=2309770) I0000 00:00:1706798549.106950 2310090 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# (DefaultActor pid=2309770) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2309770) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2309770) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2309770) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2309770) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2309770) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2309770) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2309770) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2309770) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.
# (DefaultActor pid=2309770) WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.

# %%
data = {}

# Iterate through each tuple in the first list to use as keys and create lists for their values
for metric, value in result[0]:
    data[metric] = []

# Fill the lists with values from each corresponding position in the remaining lists
for res in result:
    for i, (metric, value) in enumerate(res):
        data[metric].append(value)

# Convert the dictionary into a DataFrame
result_df = pd.DataFrame(data)

# %%
result_df.mean(axis=0)

# %% [markdown]
# ## Model Testing

# %%
def model_report_list(model, df_test):
    result = []

    x_test = df_test.iloc[:, :-1]
    y_test = df_test["Class"]

    # Get model predictions for the test data
    y_pred_prob = model.predict(x_test, verbose=0)
    
    optimal_threshold = 0.5
    
    y_pred = (y_pred_prob > optimal_threshold).astype("int32")

    df_test["PLabel"] = y_pred
    
    # Calculate F1 Score
    f1 = f1_score(y_test, y_pred)
    result.append(('F1 Score', f1))

    # Calculate AUC
    auc_score = roc_auc_score(y_test, y_pred_prob)
    result.append(('AUC', auc_score))

    # Calculate Average Precision
    avg_precision = average_precision_score(y_test, y_pred_prob)
    result.append(('Average Precision', avg_precision))
    
    # Calculate Precision
    precision = precision_score(y_test, y_pred)
    result.append(('Precision', precision))
    
    # Calculate Recall
    recall = recall_score(y_test, y_pred)
    result.append(('Recall', recall))

    confusion_mat = confusion_matrix(y_test, y_pred)

    FP = confusion_mat[0][1]
    FN = confusion_mat[1][0]

    TP = confusion_mat[1][1]
    TN = confusion_mat[0][0]

    FPR = FP / (FP + TN) if (FP + TN) > 0 else 0  # Avoid division by zero
    FNR = FN / (FN + TP) if (FN + TP) > 0 else 0  # Avoid division by zero

    result.append(('False Positive Rate', FPR))
    result.append(('False Negative Rate', FNR))

    del model
    
    return result
# Out:
# WARNING:absl:Skipping variable loading for optimizer 'Nadam', because it has 13 variables whereas the saved optimizer has 1 variables.

# %%
result = []

for _ in range(50):
    
    output_model = f"./models/i_{_}.keras"
    
    model = load_model(output_model)
    s = model_report_list(model, test_data.copy())

    result.append(s)
    del model

# %%
data = {}

# Iterate through each tuple in the first list to use as keys and create lists for their values
for metric, value in result[0]:
    data[metric] = []

# Fill the lists with values from each corresponding position in the remaining lists
for res in result:
    for i, (metric, value) in enumerate(res):
        data[metric].append(value)

# Convert the dictionary into a DataFrame
result_df = pd.DataFrame(data)

print(model_name)
print("-"*100)
print(result_df.mean(axis=0))
print("-"*100)
